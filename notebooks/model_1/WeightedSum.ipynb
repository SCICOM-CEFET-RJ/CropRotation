# %%
import numpy as np
import pandas as pd

# %%
import pulp

# %%
import tikzplotly

# %%
from src.modeling import *

# %%
from src.graphs import *

# %%
def of_net_income(_cost, _vars, _crops_year):
    return pulp.lpSum([getattr(_cost, _crops_year[i]) * _vars[i] for i in _crops_year])

def of_ua_total(_vars, _crops_year):
    return pulp.lpSum([_vars[i] for i in _crops_year])

def of_crop_diversity(_vars, _crops_year):
    return pulp.lpSum([_vars[i] for i in _crops_year])

# %%
sig = lambda sigma, NUM_ITER: 1/(1 + np.exp(sigma*(np.linspace(0, NUM_ITER, NUM_ITER)-(NUM_ITER/2))))

alpha_lin = np.linspace(0, 1, 1000)
alpha_sig_004 = sig(-0.004, 1000)
alpha_sig_06 = sig(-0.06, 1000)

l_alpha = {'alpha_lin':     alpha_lin, 
           #'alpha_sig_004': alpha_sig_004, 
           #'alpha_sig_06':  alpha_sig_06,
           }

# %%
variables = pd.read_csv('dados/al_rasheed/variables.csv', sep=';')
income = pd.read_csv('dados/al_rasheed/net_income.csv', sep=';')
constraints = pd.read_csv('dados/al_rasheed/constraints.csv', sep=';')
rotations = pd.read_csv('dados/al_rasheed/rotations.csv', sep=';').fillna(0)

# %%
YEARS = 2

# %%
crops = variables.variable.to_list()

crops_year_integer = dict(zip([f"y{i:03}_int_{j}" for i in range(1,YEARS+1) for j in crops], YEARS*crops))

crops_year_binary = dict(zip([f"y{i:03}_bin_{j}" for i in range(1,YEARS+1) for j in crops], YEARS*crops))

# %%
variables.set_index(keys='variable', inplace=True)

integer_vars = create_integer_vars(crops_year_integer, variables)

binary_vars = create_binary_vars(crops_year_binary, variables)

# %%
ofs = [of_net_income(income.loc[0,:], integer_vars, crops_year_integer),
       of_ua_total(integer_vars, crops_year_integer),
       of_crop_diversity(binary_vars, crops_year_binary)]

# %%
min_max_ofs = []
for of in ofs:
    vl = []
    for opt in [pulp.LpMinimize, pulp.LpMaximize]:
        model = pulp.LpProblem("Modelo_1", opt)
        model += of
        const_idx = add_constraints(model, integer_vars, constraints, crops_year_integer, len(crops), YEARS, const_id = 0)
        const_idx = add_binary_correlation(model, binary_vars, integer_vars, 113, const_id = const_idx)
        const_idx = add_crop_rotation_constraints(model, integer_vars, crops_year_integer, rotations, YEARS, crops, 'y{:03d}_int_{}', const_idx)

        solution = model.solve(pulp.GLPK())

        vl.append(pulp.value(model.objective))
    
    min_max_ofs.append(vl)
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/ac4e0e2e31f8454fb08ea4e96da45899-pulp.lp -o /tmp/ac4e0e2e31f8454fb08ea4e96da45899-pulp.sol
# Reading problem data from '/tmp/ac4e0e2e31f8454fb08ea4e96da45899-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 311 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.520000000e+05 inf =   2.400e+04 (2)
#       2: obj =   2.520000000e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +     2: mip =     not found yet >=              -inf        (1; 0)
# +     4: >>>>>   2.520000000e+05 >=   2.520000000e+05   0.0% (1; 0)
# +     4: mip =   2.520000000e+05 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (168318 bytes)
# Writing MIP solution to '/tmp/ac4e0e2e31f8454fb08ea4e96da45899-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/be9f36ed90bc441c82ea35d8e51a6add-pulp.lp -o /tmp/be9f36ed90bc441c82ea35d8e51a6add-pulp.sol
# Reading problem data from '/tmp/be9f36ed90bc441c82ea35d8e51a6add-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 311 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.520000000e+05 inf =   2.400e+04 (2)
#       2: obj =   2.520000000e+05 inf =   0.000e+00 (0)
# *    18: obj =   1.257180068e+07 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 12542636.8
# Solution found by heuristic: 12559922.4
# +    67: mip =   1.255992240e+07 <=     tree is empty   0.0% (0; 25)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (178578 bytes)
# Writing MIP solution to '/tmp/be9f36ed90bc441c82ea35d8e51a6add-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/38643b0b4e1947659950b44fb2691113-pulp.lp -o /tmp/38643b0b4e1947659950b44fb2691113-pulp.sol
# Reading problem data from '/tmp/38643b0b4e1947659950b44fb2691113-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 309 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   3.000000000e+03 inf =   2.400e+04 (2)
#       2: obj =   3.000000000e+03 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +     2: mip =     not found yet >=              -inf        (1; 0)
# +     4: >>>>>   3.000000000e+03 >=   3.000000000e+03   0.0% (1; 0)
# +     4: mip =   3.000000000e+03 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (168318 bytes)
# Writing MIP solution to '/tmp/38643b0b4e1947659950b44fb2691113-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/025f24fa685d4da1b6d4defec197e3a4-pulp.lp -o /tmp/025f24fa685d4da1b6d4defec197e3a4-pulp.sol
# Reading problem data from '/tmp/025f24fa685d4da1b6d4defec197e3a4-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 309 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   3.000000000e+03 inf =   2.400e+04 (2)
#       2: obj =   3.000000000e+03 inf =   0.000e+00 (0)
# *    18: obj =   9.310000000e+03 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# +    20: >>>>>   9.310000000e+03 <=   9.310000000e+03   0.0% (1; 0)
# +    20: mip =   9.310000000e+03 <=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (168318 bytes)
# Writing MIP solution to '/tmp/025f24fa685d4da1b6d4defec197e3a4-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/15caf365252b4ea5b9ddae238400eeb0-pulp.lp -o /tmp/15caf365252b4ea5b9ddae238400eeb0-pulp.sol
# Reading problem data from '/tmp/15caf365252b4ea5b9ddae238400eeb0-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 309 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   0.000000000e+00 inf =   2.400e+04 (2)
#       2: obj =   1.572327044e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +     2: mip =     not found yet >=              -inf        (1; 0)
# +     4: >>>>>   2.000000000e+00 >=   2.000000000e+00   0.0% (1; 0)
# +     4: mip =   2.000000000e+00 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (168318 bytes)
# Writing MIP solution to '/tmp/15caf365252b4ea5b9ddae238400eeb0-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/d4bb83d8cc8d4eb6b11fc50ff1378366-pulp.lp -o /tmp/d4bb83d8cc8d4eb6b11fc50ff1378366-pulp.sol
# Reading problem data from '/tmp/d4bb83d8cc8d4eb6b11fc50ff1378366-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 309 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =  -0.000000000e+00 inf =   2.400e+04 (2)
#       2: obj =   1.572327044e+00 inf =   0.000e+00 (0)
# *    48: obj =   2.400000000e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    48: mip =     not found yet <=              +inf        (1; 0)
# +    48: >>>>>   2.400000000e+01 <=   2.400000000e+01   0.0% (1; 0)
# +    48: mip =   2.400000000e+01 <=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (168042 bytes)
# Writing MIP solution to '/tmp/d4bb83d8cc8d4eb6b11fc50ff1378366-pulp.sol'...

# %%
ofs_norn = [ min_max_normalization(ofs[idx], min_max_ofs[idx]) for idx in range(len(ofs))]

# %%
solution_lst = []
for key in l_alpha:
    aph = l_alpha[key]
    for i_alpha in range(0, len(aph)):            
        alpha = aph[i_alpha]
        model = pulp.LpProblem("First_Model", pulp.LpMaximize)

        weighted_sum(model, ofs_norn, [alpha, 0.5 * (1 - alpha), 0.5 * (1 - alpha)]) 

        const_idx = add_constraints(model, integer_vars, constraints, crops_year_integer, len(crops), YEARS, const_id = 0)
        const_idx = add_binary_correlation(model, binary_vars, integer_vars, 113, const_id = const_idx)
        const_idx = add_crop_rotation_constraints(model, integer_vars, crops_year_integer, rotations, YEARS, crops, 'y{:03d}_int_{}', const_idx)

        solution = model.solve(pulp.GLPK())

        integer_var_values = {key: pulp.value(value) for key, value in integer_vars.items()}
        binary_var_values = {key: pulp.value(value) for key, value in binary_vars.items()}

        ney_incone_ofs_values = sum_cost_of_values(income.loc[0,:], integer_var_values, crops_year_integer, 'net_income', 0, 4)
        us_ofs_values = sum_of_var_values(integer_var_values, 'ua', 0, 4)
        crop_diversity_ofs_values = sum_of_var_values(binary_var_values, 'crop_diversity', 0, 4)


        solution_lst.append([key,
                            i_alpha,
                            alpha,
                            str(pulp.LpStatus[solution])] +
                            list(integer_var_values.values())+
                            list(binary_var_values.values())+
                            [pulp.value(model.objective)] +
                            list(ney_incone_ofs_values.values())+
                            list(us_ofs_values.values())+
                            list(crop_diversity_ofs_values.values())
                            )
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/af8e6b432a794cc6903663d3dc03b2be-pulp.lp -o /tmp/af8e6b432a794cc6903663d3dc03b2be-pulp.sol
# Reading problem data from '/tmp/af8e6b432a794cc6903663d3dc03b2be-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.377179081e-01 inf =   2.400e+04 (2)
#       2: obj =   2.734526136e-01 inf =   0.000e+00 (0)
# *    57: obj =   1.283172454e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    57: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.28317245354
# +    57: mip =   1.283172454e+00 <=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (168042 bytes)
# Writing MIP solution to '/tmp/af8e6b432a794cc6903663d3dc03b2be-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/1316e809baff43cbb3ce89d982143282-pulp.lp -o /tmp/1316e809baff43cbb3ce89d982143282-pulp.sol
# Reading problem data from '/tmp/1316e809baff43cbb3ce89d982143282-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.375004473e-01 inf =   2.400e+04 (2)
#       2: obj =   2.731993824e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.282482137e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.28248218377
# +    60: mip =   1.282482184e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/1316e809baff43cbb3ce89d982143282-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c165adc5813245c0a2a79e6ade54c0a8-pulp.lp -o /tmp/c165adc5813245c0a2a79e6ade54c0a8-pulp.sol
# Reading problem data from '/tmp/c165adc5813245c0a2a79e6ade54c0a8-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.372829866e-01 inf =   2.400e+04 (2)
#       2: obj =   2.729461512e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.281791820e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.281791914
# +    60: mip =   1.281791914e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/c165adc5813245c0a2a79e6ade54c0a8-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/28264cfcb70d4fe6bf195b435a98de69-pulp.lp -o /tmp/28264cfcb70d4fe6bf195b435a98de69-pulp.sol
# Reading problem data from '/tmp/28264cfcb70d4fe6bf195b435a98de69-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.370655258e-01 inf =   2.400e+04 (2)
#       2: obj =   2.726929199e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.281101503e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.28110164422
# +    60: mip =   1.281101644e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/28264cfcb70d4fe6bf195b435a98de69-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/6319b8f9b8b2460cb429c34b7ccbe3fc-pulp.lp -o /tmp/6319b8f9b8b2460cb429c34b7ccbe3fc-pulp.sol
# Reading problem data from '/tmp/6319b8f9b8b2460cb429c34b7ccbe3fc-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.368480651e-01 inf =   2.400e+04 (2)
#       2: obj =   2.724396887e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.280411186e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.28041137446
# +    60: mip =   1.280411374e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/6319b8f9b8b2460cb429c34b7ccbe3fc-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c75d39bbdfea4e79b11a988f0b453f9c-pulp.lp -o /tmp/c75d39bbdfea4e79b11a988f0b453f9c-pulp.sol
# Reading problem data from '/tmp/c75d39bbdfea4e79b11a988f0b453f9c-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.366306043e-01 inf =   2.400e+04 (2)
#       2: obj =   2.721864575e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.279720869e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27972110468
# +    60: mip =   1.279721105e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/c75d39bbdfea4e79b11a988f0b453f9c-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c537bc8136fc44128be7175c1777b40a-pulp.lp -o /tmp/c537bc8136fc44128be7175c1777b40a-pulp.sol
# Reading problem data from '/tmp/c537bc8136fc44128be7175c1777b40a-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.364131436e-01 inf =   2.400e+04 (2)
#       2: obj =   2.719332263e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.279030552e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.28010035927
# +    75: mip =   1.280100359e+00 <=     tree is empty   0.0% (0; 13)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/c537bc8136fc44128be7175c1777b40a-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/e718443a876c459284c021546e869593-pulp.lp -o /tmp/e718443a876c459284c021546e869593-pulp.sol
# Reading problem data from '/tmp/e718443a876c459284c021546e869593-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.361956828e-01 inf =   2.400e+04 (2)
#       2: obj =   2.716799950e-01 inf =   0.000e+00 (0)
# *    58: obj =   1.278340235e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    58: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27958834356
# +    76: mip =   1.279588344e+00 <=     tree is empty   0.0% (0; 11)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (181684 bytes)
# Writing MIP solution to '/tmp/e718443a876c459284c021546e869593-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/3bd4b551ac3849efa6aead77f50c214b-pulp.lp -o /tmp/3bd4b551ac3849efa6aead77f50c214b-pulp.sol
# Reading problem data from '/tmp/3bd4b551ac3849efa6aead77f50c214b-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.359782221e-01 inf =   2.400e+04 (2)
#       2: obj =   2.714267638e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.278253676e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27825364754
# +    62: mip =   1.278253648e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/3bd4b551ac3849efa6aead77f50c214b-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/3e23fe99c9db413b8ecb066881f5329f-pulp.lp -o /tmp/3e23fe99c9db413b8ecb066881f5329f-pulp.sol
# Reading problem data from '/tmp/3e23fe99c9db413b8ecb066881f5329f-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.357607613e-01 inf =   2.400e+04 (2)
#       2: obj =   2.711735326e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.277638828e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27763879679
# +    62: mip =   1.277638797e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/3e23fe99c9db413b8ecb066881f5329f-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/52ae802a1f3c48109b642fb9855aabbc-pulp.lp -o /tmp/52ae802a1f3c48109b642fb9855aabbc-pulp.sol
# Reading problem data from '/tmp/52ae802a1f3c48109b642fb9855aabbc-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.355433006e-01 inf =   2.400e+04 (2)
#       2: obj =   2.709203014e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.277023981e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27702394604
# +    62: mip =   1.277023946e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/52ae802a1f3c48109b642fb9855aabbc-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/3d80f05660324c678f07e79f68542b2d-pulp.lp -o /tmp/3d80f05660324c678f07e79f68542b2d-pulp.sol
# Reading problem data from '/tmp/3d80f05660324c678f07e79f68542b2d-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.353258398e-01 inf =   2.400e+04 (2)
#       2: obj =   2.706670701e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.276409134e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27640909529
# +    62: mip =   1.276409095e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/3d80f05660324c678f07e79f68542b2d-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/af255f25083c49ed99445bfa2c7d4d9c-pulp.lp -o /tmp/af255f25083c49ed99445bfa2c7d4d9c-pulp.sol
# Reading problem data from '/tmp/af255f25083c49ed99445bfa2c7d4d9c-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.351083791e-01 inf =   2.400e+04 (2)
#       2: obj =   2.704138389e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.275794287e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27579424454
# +    62: mip =   1.275794245e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/af255f25083c49ed99445bfa2c7d4d9c-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/9b1b111f37184e7fbefc212dae39bcea-pulp.lp -o /tmp/9b1b111f37184e7fbefc212dae39bcea-pulp.sol
# Reading problem data from '/tmp/9b1b111f37184e7fbefc212dae39bcea-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.348909183e-01 inf =   2.400e+04 (2)
#       2: obj =   2.701606077e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.275179439e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27517939379
# +    62: mip =   1.275179394e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/9b1b111f37184e7fbefc212dae39bcea-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/961c07359d34464c8448555317ce191e-pulp.lp -o /tmp/961c07359d34464c8448555317ce191e-pulp.sol
# Reading problem data from '/tmp/961c07359d34464c8448555317ce191e-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.346734576e-01 inf =   2.400e+04 (2)
#       2: obj =   2.699073764e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.274564592e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.27456454304
# +    62: mip =   1.274564543e+00 <=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/961c07359d34464c8448555317ce191e-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/f7bdd0b550014752b7e7e283b00b342e-pulp.lp -o /tmp/f7bdd0b550014752b7e7e283b00b342e-pulp.sol
# Reading problem data from '/tmp/f7bdd0b550014752b7e7e283b00b342e-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.344559968e-01 inf =   2.400e+04 (2)
#       2: obj =   2.696541452e-01 inf =   0.000e+00 (0)
# *    60: obj =   1.273949745e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    60: mip =     not found yet <=              +inf        (1; 0)
# +    76: >>>>>   1.275490895e+00 <=   1.275492454e+00 < 0.1% (8; 0)
# Solution found by heuristic: 1.27549112773
# +    79: >>>>>   1.275492440e+00 <=   1.275492440e+00   0.0% (2; 7)
# +    79: mip =   1.275492440e+00 <=     tree is empty   0.0% (0; 15)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (181946 bytes)
# Writing MIP solution to '/tmp/f7bdd0b550014752b7e7e283b00b342e-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/38185bdb8f534962a8e7c11af421b5a7-pulp.lp -o /tmp/38185bdb8f534962a8e7c11af421b5a7-pulp.sol
# Reading problem data from '/tmp/38185bdb8f534962a8e7c11af421b5a7-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.342385361e-01 inf =   2.400e+04 (2)
#       2: obj =   2.694009140e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.274247908e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.274978792e+00 <=   1.274246262e+00 < 0.1% (10; 0)
# +    78: mip =   1.274978792e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/38185bdb8f534962a8e7c11af421b5a7-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/9e418f8cf87f4a93bca010f31b3a47d8-pulp.lp -o /tmp/9e418f8cf87f4a93bca010f31b3a47d8-pulp.sol
# Reading problem data from '/tmp/9e418f8cf87f4a93bca010f31b3a47d8-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.340210753e-01 inf =   2.400e+04 (2)
#       2: obj =   2.691476828e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.273690124e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.274466688e+00 <=   1.273688375e+00 < 0.1% (10; 0)
# +    78: mip =   1.274466688e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/9e418f8cf87f4a93bca010f31b3a47d8-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/9b303b6fd5464fb385e825abb3a81521-pulp.lp -o /tmp/9b303b6fd5464fb385e825abb3a81521-pulp.sol
# Reading problem data from '/tmp/9b303b6fd5464fb385e825abb3a81521-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.338036146e-01 inf =   2.400e+04 (2)
#       2: obj =   2.688944515e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.273132340e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.273954584e+00 <=   1.273130488e+00 < 0.1% (10; 0)
# +    78: mip =   1.273954584e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/9b303b6fd5464fb385e825abb3a81521-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/96071a6800ae46ed82c29eccd84058ec-pulp.lp -o /tmp/96071a6800ae46ed82c29eccd84058ec-pulp.sol
# Reading problem data from '/tmp/96071a6800ae46ed82c29eccd84058ec-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.335861538e-01 inf =   2.400e+04 (2)
#       2: obj =   2.686412203e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.272574556e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.273442480e+00 <=   1.272572601e+00 < 0.1% (10; 0)
# +    78: mip =   1.273442480e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/96071a6800ae46ed82c29eccd84058ec-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/cdd0805d83b742c78c87f1df4bae387a-pulp.lp -o /tmp/cdd0805d83b742c78c87f1df4bae387a-pulp.sol
# Reading problem data from '/tmp/cdd0805d83b742c78c87f1df4bae387a-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.333686931e-01 inf =   2.400e+04 (2)
#       2: obj =   2.683879891e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.272016772e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.272930376e+00 <=   1.272014714e+00 < 0.1% (10; 0)
# +    78: mip =   1.272930376e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/cdd0805d83b742c78c87f1df4bae387a-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/2e82864bc5b245068ea9aed55f97986d-pulp.lp -o /tmp/2e82864bc5b245068ea9aed55f97986d-pulp.sol
# Reading problem data from '/tmp/2e82864bc5b245068ea9aed55f97986d-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.331512323e-01 inf =   2.400e+04 (2)
#       2: obj =   2.681347578e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.271458988e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.272418272e+00 <=   1.271456827e+00 < 0.1% (10; 0)
# +    78: mip =   1.272418272e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/2e82864bc5b245068ea9aed55f97986d-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/3f72306a731e498e91e881cd345cb461-pulp.lp -o /tmp/3f72306a731e498e91e881cd345cb461-pulp.sol
# Reading problem data from '/tmp/3f72306a731e498e91e881cd345cb461-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.329337715e-01 inf =   2.400e+04 (2)
#       2: obj =   2.678815266e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.270901204e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.271906168e+00 <=   1.270898940e+00 < 0.1% (10; 0)
# +    78: mip =   1.271906168e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/3f72306a731e498e91e881cd345cb461-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/66f0ac6739c14ea2bd0c2d787b4adc93-pulp.lp -o /tmp/66f0ac6739c14ea2bd0c2d787b4adc93-pulp.sol
# Reading problem data from '/tmp/66f0ac6739c14ea2bd0c2d787b4adc93-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.327163108e-01 inf =   2.400e+04 (2)
#       2: obj =   2.676282954e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.270343419e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.271394064e+00 <=   1.270341053e+00 < 0.1% (10; 0)
# +    78: mip =   1.271394064e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/66f0ac6739c14ea2bd0c2d787b4adc93-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/b7a20ef311514296a47248701a1593d5-pulp.lp -o /tmp/b7a20ef311514296a47248701a1593d5-pulp.sol
# Reading problem data from '/tmp/b7a20ef311514296a47248701a1593d5-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.324988500e-01 inf =   2.400e+04 (2)
#       2: obj =   2.673750642e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.269785635e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.270881961e+00 <=   1.269783166e+00 < 0.1% (10; 0)
# +    78: mip =   1.270881961e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/b7a20ef311514296a47248701a1593d5-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/f00d2dd1f1a1468186750b34b4fe1d80-pulp.lp -o /tmp/f00d2dd1f1a1468186750b34b4fe1d80-pulp.sol
# Reading problem data from '/tmp/f00d2dd1f1a1468186750b34b4fe1d80-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.322813893e-01 inf =   2.400e+04 (2)
#       2: obj =   2.671218329e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.269227851e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.270369857e+00 <=   1.269225279e+00 < 0.1% (10; 0)
# +    78: mip =   1.270369857e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/f00d2dd1f1a1468186750b34b4fe1d80-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/9b85be8359d34cfabfe1aae70530558e-pulp.lp -o /tmp/9b85be8359d34cfabfe1aae70530558e-pulp.sol
# Reading problem data from '/tmp/9b85be8359d34cfabfe1aae70530558e-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.320639285e-01 inf =   2.400e+04 (2)
#       2: obj =   2.668686017e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.268670067e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.269857753e+00 <=   1.268667392e+00 < 0.1% (10; 0)
# +    78: mip =   1.269857753e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/9b85be8359d34cfabfe1aae70530558e-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/959b78f428314c189b8486e65c43eaaf-pulp.lp -o /tmp/959b78f428314c189b8486e65c43eaaf-pulp.sol
# Reading problem data from '/tmp/959b78f428314c189b8486e65c43eaaf-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.318464678e-01 inf =   2.400e+04 (2)
#       2: obj =   2.666153705e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.268112283e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    78: >>>>>   1.269345649e+00 <=   1.268109505e+00 < 0.1% (10; 0)
# +    78: mip =   1.269345649e+00 <=     tree is empty   0.0% (0; 19)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (174166 bytes)
# Writing MIP solution to '/tmp/959b78f428314c189b8486e65c43eaaf-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/334472ce930a4afbbc266caffa745a03-pulp.lp -o /tmp/334472ce930a4afbbc266caffa745a03-pulp.sol
# Reading problem data from '/tmp/334472ce930a4afbbc266caffa745a03-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.316290070e-01 inf =   2.400e+04 (2)
#       2: obj =   2.663621393e-01 inf =   0.000e+00 (0)
# *    62: obj =   1.267554499e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    62: mip =     not found yet <=              +inf        (1; 0)
# +    76: >>>>>   1.268833545e+00 <=   1.268836454e+00 < 0.1% (8; 0)
# Solution found by heuristic: 1.2688339787
# +    79: >>>>>   1.268836429e+00 <=   1.268836429e+00   0.0% (2; 7)
# +    79: mip =   1.268836429e+00 <=     tree is empty   0.0% (0; 15)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# ...
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.243176399e-02 inf =   2.400e+04 (2)
#       2: obj =   2.275369828e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.020150480e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.0185829853
# Solution found by heuristic: 1.01975858945
# +    48: mip =   1.019758589e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177288 bytes)
# Writing MIP solution to '/tmp/6e0a98a1d3e244f090fb84956f18358a-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/fe2f0d40908249eb8b907311d3646d39-pulp.lp -o /tmp/fe2f0d40908249eb8b907311d3646d39-pulp.sol
# Reading problem data from '/tmp/fe2f0d40908249eb8b907311d3646d39-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.221430324e-02 inf =   2.400e+04 (2)
#       2: obj =   2.250046705e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.020293728e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01863711899
# Solution found by heuristic: 1.01983814809
# +    46: mip =   1.019838148e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/fe2f0d40908249eb8b907311d3646d39-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/41a21c3d20674d52a935ba85a5f7f9ff-pulp.lp -o /tmp/41a21c3d20674d52a935ba85a5f7f9ff-pulp.sol
# Reading problem data from '/tmp/41a21c3d20674d52a935ba85a5f7f9ff-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 329 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.199684249e-02 inf =   2.400e+04 (2)
#       2: obj =   2.224723582e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.020436976e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01869125267
# Solution found by heuristic: 1.01991770673
# +    46: mip =   1.019917707e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/41a21c3d20674d52a935ba85a5f7f9ff-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/6825f7cbd494454d8f8d265a9476119a-pulp.lp -o /tmp/6825f7cbd494454d8f8d265a9476119a-pulp.sol
# Reading problem data from '/tmp/6825f7cbd494454d8f8d265a9476119a-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.177938174e-02 inf =   2.400e+04 (2)
#       2: obj =   2.199400459e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.020580223e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01874538636
# Solution found by heuristic: 1.01999726538
# +    46: mip =   1.019997265e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/6825f7cbd494454d8f8d265a9476119a-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/3a711350b9904e67be4330e18b9f4f69-pulp.lp -o /tmp/3a711350b9904e67be4330e18b9f4f69-pulp.sol
# Reading problem data from '/tmp/3a711350b9904e67be4330e18b9f4f69-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 329 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.156192099e-02 inf =   2.400e+04 (2)
#       2: obj =   2.174077337e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.020723471e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01879952005
# Solution found by heuristic: 1.02007682402
# +    46: mip =   1.020076824e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/3a711350b9904e67be4330e18b9f4f69-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/5c134c9717f64c02b497245cf6c39b14-pulp.lp -o /tmp/5c134c9717f64c02b497245cf6c39b14-pulp.sol
# Reading problem data from '/tmp/5c134c9717f64c02b497245cf6c39b14-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 329 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.134446023e-02 inf =   2.400e+04 (2)
#       2: obj =   2.148754214e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.020866719e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01885365374
# Solution found by heuristic: 1.02015638266
# +    46: mip =   1.020156383e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/5c134c9717f64c02b497245cf6c39b14-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c698c0c4bb9d48ab8a0e49c524e16be0-pulp.lp -o /tmp/c698c0c4bb9d48ab8a0e49c524e16be0-pulp.sol
# Reading problem data from '/tmp/c698c0c4bb9d48ab8a0e49c524e16be0-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 329 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.112699948e-02 inf =   2.400e+04 (2)
#       2: obj =   2.123431091e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.021009967e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01890778742
# Solution found by heuristic: 1.0202359413
# +    46: mip =   1.020235941e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/c698c0c4bb9d48ab8a0e49c524e16be0-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/a7b46c0aac384fefa8409bb6118d0741-pulp.lp -o /tmp/a7b46c0aac384fefa8409bb6118d0741-pulp.sol
# Reading problem data from '/tmp/a7b46c0aac384fefa8409bb6118d0741-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.090953873e-02 inf =   2.400e+04 (2)
#       2: obj =   2.098107968e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.021153214e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01896192111
# Solution found by heuristic: 1.02031549994
# +    46: mip =   1.020315500e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/a7b46c0aac384fefa8409bb6118d0741-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/0d10ead3029f4b30b76f1fece3f0e453-pulp.lp -o /tmp/0d10ead3029f4b30b76f1fece3f0e453-pulp.sol
# Reading problem data from '/tmp/0d10ead3029f4b30b76f1fece3f0e453-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 326 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.069207798e-02 inf =   2.400e+04 (2)
#       2: obj =   2.072784845e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.021296462e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.0190160548
# Solution found by heuristic: 1.02039505859
# +    46: mip =   1.020395059e+00 <=     tree is empty   0.0% (0; 17)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (177618 bytes)
# Writing MIP solution to '/tmp/0d10ead3029f4b30b76f1fece3f0e453-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/3eea9d6622a74e1dbe2b3edc5ef16e6f-pulp.lp -o /tmp/3eea9d6622a74e1dbe2b3edc5ef16e6f-pulp.sol
# Reading problem data from '/tmp/3eea9d6622a74e1dbe2b3edc5ef16e6f-pulp.lp'...
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# 315 lines were read
# GLPK Integer Optimizer 5.0
# 88 rows, 48 columns, 430 non-zeros
# 48 integer variables, 24 of which are binary
# Preprocessing...
# 24 constraint coefficient(s) were reduced
# 64 rows, 48 columns, 242 non-zeros
# 48 integer variables, 24 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.260e+03  ratio =  2.260e+03
# GM: min|aij| =  4.453e-01  max|aij| =  2.246e+00  ratio =  5.042e+00
# EQ: min|aij| =  2.100e-01  max|aij| =  1.000e+00  ratio =  4.761e+00
# 2N: min|aij| =  1.104e-01  max|aij| =  1.562e+00  ratio =  1.416e+01
# Constructing initial basis...
# Size of triangular part is 64
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 64 rows, 48 columns, 242 non-zeros
#       0: obj =   2.047461723e-02 inf =   2.400e+04 (2)
#       2: obj =   2.047461723e-02 inf =   0.000e+00 (0)
# *    18: obj =   1.021439710e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    18: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1.01907018848
# Solution found by heuristic: 1.02047461723
# +    67: mip =   1.020474617e+00 <=     tree is empty   0.0% (0; 25)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (178578 bytes)
# Writing MIP solution to '/tmp/3eea9d6622a74e1dbe2b3edc5ef16e6f-pulp.sol'...

# %%
columns = ["alpha_type", "iter", "alpha", "status"] +\
         list(integer_var_values.keys()) + \
         list(binary_var_values.keys()) + \
         ['OF_Optimized'] + \
         list(ney_incone_ofs_values.keys()) + \
         list(us_ofs_values.keys()) + \
         list(crop_diversity_ofs_values.keys())

# %%
results = pd.DataFrame(solution_lst, columns=columns)

# %%
l = {'alpha': 'λ', 'OF_Optimized': 'g'}

fig = plot_one_scatter(results, 'alpha', 'OF_Optimized', l)

fig.show()
#fig.write_image('images/fig_mdl2_z2y_vs_lambda.svg')
#tikzplotly.save("figure.tex", fig)

# %%
l = {'alpha': 'λ', 'net_income_total': 'g<sub>1</sub> (USD)'}

fig = plot_one_scatter(results, 'alpha', 'net_income_total', l)

fig.show()
#fig.write_image('images/fig_mdl2_z2y_vs_lambda.svg')
#tikzplotly.save("figure.tex", fig)

# %%
cm = ['rgb(77,77,77)', 'rgb(153, 153, 153)', 'rgb(186,186,186)', 'rgb(244,165,130)', 'rgb(214,96,77)','rgb(230, 39, 23)']
cm = ['rgb(77,77,77)', 'rgb(153, 153, 153)', 'rgb(214,96,77)','rgb(230, 39, 23)']

# %%
'y001_int_Wheat', 'y001_int_Beetroot', 'y001_int_Cloves', 'y001_int_Broad_Bean', 'y001_int_Green_Onion', 'y001_int_Autumn_Potatoes', 
'y001_int_Sunflower', 'y001_int_Maize', 'y001_int_Tomatoes', 'y001_int_Cucumbers', 'y001_int_Okra', 'y001_int_Watermelon', 

'y002_int_Wheat', 'y002_int_Beetroot', 'y002_int_Cloves', 'y002_int_Broad_Bean', 'y002_int_Green_Onion', 'y002_int_Autumn_Potatoes', 
'y002_int_Sunflower', 'y002_int_Maize', 'y002_int_Tomatoes', 'y002_int_Cucumbers', 'y002_int_Okra', 'y002_int_Watermelon',
# Out:
# ('y002_int_Sunflower',
#  'y002_int_Maize',
#  'y002_int_Tomatoes',
#  'y002_int_Cucumbers',
#  'y002_int_Okra',
#  'y002_int_Watermelon')

# %%
l = {   'alpha':'λ', 
                                        'f1': 'g<sub>1</sub> (USD)',
                                        'X_1_1':'u<sub>1</sub>', 
                                        'X_1_2':'u<sub>2</sub>', 
                                        'X_1_3':'u<sub>3</sub>', 
                                        'X_1_4':'u<sub>4</sub>', 
                                        'X_1_5':'u<sub>5</sub>', 
                                        'X_1_6':'u<sub>6</sub>', 
                                        'X_1_7':'u<sub>7</sub>', 
                                        'X_1_8':'u<sub>8</sub>', 
                                        'X_1_9':'u<sub>9</sub>', 
                                        'X_1_10':'u<sub>10</sub>', 
                                        'X_1_11':'u<sub>11</sub>', 
                                        'X_1_12':'u<sub>12</sub>'}

# %%
px.data.iris()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
dt = results
fig1 = px.parallel_coordinates(dt, 
                             dimensions=['alpha',
                                         'y001_int_Wheat', 'y001_int_Beetroot', 'y001_int_Cloves', 'y001_int_Broad_Bean', 'y001_int_Green_Onion', 'y001_int_Autumn_Potatoes', 
'y001_int_Sunflower', 'y001_int_Maize', 'y001_int_Tomatoes', 'y001_int_Cucumbers', 'y001_int_Okra', 'y001_int_Watermelon'],
                             color="net_income_total", 
                             color_continuous_scale=cm,
                             labels=None,
                             color_continuous_midpoint=2,
                             range_color = [dt.net_income_total.min(), dt.net_income_total.max()])

fig1.show()

# %%
tikzplotly.save("figure.tex", fig)
# Out:
# /home/roberto/anaconda3/envs/OtimizacaoLinear/lib/python3.10/site-packages/tikzplotly/_save.py:59: UserWarning:
#
# Trace type splom is not supported yet.

# %%
_columns = ["alpha","net_income_total", "crop_diversity_total"]
fig = px.scatter_matrix(dt,
    dimensions= _columns,
    #color="species", symbol="species",
    #title="Scatter matrix of iris data set",
    labels={col:col.replace('_', ' ') for col in _columns}
    ) # remove underscore
fig.update_traces(diagonal_visible=False,
                  marker=dict(color='rgb(115, 115, 115)',
                              size=3)
                )

fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    yaxis=dict(
        showgrid=True,
        zeroline=False,
        showline=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),

    showlegend=True,
    autosize=True,
    #plot_bgcolor='#000000'
)

fig.show()
